# %% [markdown]
# ## Cryptol AES Implementation ##
# Copyright (c) 2010-2013, Galois Inc.
# [www.cryptol.net](http://www.cryptol.net)
# You can freely use this source code for educational purposes.
#
# This is a fairly close implementation of the [FIPS-197 standard](http://csrc.nist.gov/publications/fips/fips197/fips-197.pdf).

# %% [markdown]
# ### Key size ###
#
# Let `Nk` be the number of blocks in the key. This must be one of `4` (AES128), `6` (AES192), or `8` (AES256).
#
# Aside from this line, no other code below needs to change for implementing AES128, AES192, or AES256.

# %%
type Nk = 4
type AESKeySize  = (Nk*32)
# Out:
# Loading module Prelude
# Loading module Notebook

# %% [markdown]
# Number of blocks and rounds

# %%
type Nb = 4
type Nr = 6 + Nk
# Out:
# Loading module Prelude
# Loading module Notebook

# %% [markdown]
# Helper type definitions

# %%
type GF28        = [8]
type State       = [4][Nb]GF28
type RoundKey    = State
type KeySchedule = (RoundKey, [Nr-1]RoundKey, RoundKey)
# Out:
# Loading module Prelude
# Loading module Notebook

# %% [markdown]
# $GF(2^8)$ operations

# %%
gf28Add : {n} (fin n) => [n]GF28 -> GF28
gf28Add ps = sums ! 0
  where sums = [zero] # [  p ^ s | p <- ps | s <- sums ]

irreducible = <| x^^8 + x^^4 + x^^3 + x + 1 |>

gf28Mult : (GF28, GF28) -> GF28
gf28Mult (x, y) = pmod(pmult x y) irreducible

gf28Pow : (GF28, [8]) -> GF28
gf28Pow (n, k) = pow k
  where   sq x  = gf28Mult (x, x)
          odd x = x ! 0
          pow i = if i == 0 then 1
                  else if odd i
                       then gf28Mult(n, sq (pow (i >> 1)))
                       else sq (pow (i >> 1))

gf28Inverse : GF28 -> GF28
gf28Inverse x = gf28Pow (x, 254)

gf28DotProduct : {n} (fin n) => ([n]GF28, [n]GF28) -> GF28
gf28DotProduct (xs, ys) = gf28Add [ gf28Mult (x, y) | x <- xs
                                                    | y <- ys ]

gf28VectorMult : {n, m} (fin n) => ([n]GF28, [m][n]GF28) -> [m]GF28
gf28VectorMult (v, ms) = [ gf28DotProduct(v, m) | m <- ms ]

gf28MatrixMult : {n, m, k} (fin m) => ([n][m]GF28, [m][k]GF28) -> [n][k]GF28
gf28MatrixMult (xss, yss) = [ gf28VectorMult(xs, yss') | xs <- xss ]
   where yss' = transpose yss
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# The affine transform and its inverse

# %%
xformByte : GF28 -> GF28
xformByte b = gf28Add [b, (b >>> 4), (b >>> 5), (b >>> 6), (b >>> 7), c]
   where c = 0x63

xformByte' : GF28 -> GF28
xformByte' b = gf28Add [(b >>> 2), (b >>> 5), (b >>> 7), d] where d = 0x05
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# The S-box

# %%
sbox : [256]GF28
sbox = [
   
   ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# The SubBytes transform and its inverse

# %%
SubByte : GF28 -> GF28
SubByte b = xformByte (gf28Inverse b)

SubByte' : GF28 -> GF28
SubByte' b = sbox@b

SubBytes : State -> State
SubBytes state = [ [ SubByte' b | b <- row ] | row <- state ]


InvSubByte : GF28 -> GF28
InvSubByte b = gf28Inverse (xformByte' b)

InvSubBytes : State -> State
InvSubBytes state =[ [ InvSubByte b | b <- row ] | row <- state ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# The ShiftRows transform and its inverse

# %%
ShiftRows : State -> State
ShiftRows state = [ row <<< shiftAmount | row <- state
                                        | shiftAmount <- [0 .. 3]
                  ]

InvShiftRows : State -> State
InvShiftRows state = [ row >>> shiftAmount | row <- state
                                           | shiftAmount <- [0 .. 3]
                     ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# The MixColumns transform and its inverse

# %%
MixColumns : State -> State
MixColumns state = gf28MatrixMult (m, state)
    where m = [[2, 3, 1, 1],
               [1, 2, 3, 1],
               [1, 1, 2, 3],
               [3, 1, 1, 2]]

InvMixColumns : State -> State
InvMixColumns state = gf28MatrixMult (m, state)
    where m = [[0x0e, 0x0b, 0x0d, 0x09],
               [0x09, 0x0e, 0x0b, 0x0d],
               [0x0d, 0x09, 0x0e, 0x0b],
               [0x0b, 0x0d, 0x09, 0x0e]]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# The AddRoundKey transform

# %%
AddRoundKey : (RoundKey, State) -> State
AddRoundKey (rk, s) = rk ^ s
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# Key expansion

# %%
Rcon : [8] -> [4]GF28
Rcon i = [(gf28Pow (<| x |>, i-1)), 0, 0, 0]

SubWord : [4]GF28 -> [4]GF28
SubWord bs = [ SubByte b | b <- bs ]

RotWord : [4]GF28 -> [4]GF28
RotWord [a0, a1, a2, a3] = [a1, a2, a3, a0]

NextWord : ([8],[4][8],[4][8]) -> [4][8]
NextWord(i, prev, old) = old ^ mask
   where mask = if i % `Nk == 0
                then SubWord(RotWord(prev)) ^ Rcon (i / `Nk)
                else if (`Nk > 6) && (i % `Nk == 4)
                     then SubWord(prev)
                     else prev


ExpandKeyForever : [Nk][4][8] -> [inf]RoundKey
ExpandKeyForever seed = [ transpose g | g <- groupBy`{4} (keyWS seed) ]

keyWS : [Nk][4][8] -> [inf][4][8]
keyWS seed    = ret where 
          ret = seed # [ NextWord(i, prev, old)
                       | i    <- [ `Nk ... ]
                       | prev <- drop`{Nk-1} ret
                       | old  <- ret
                       ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %%
checkKey = take`{16} (drop`{8} (keyWS ["abcd", "defg", "1234", "5678"]))
checkKey2 = [transpose g | g <- groupBy`{4}checkKey]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %%
checkKey
checkKey2
# Out:
# [[137, 151, 138, 153], [136, 10, 136, 12], [184, 165, 185, 173],
#  [189, 60, 191, 52], [102, 159, 146, 227], [238, 149, 26, 239],
#  [86, 48, 163, 66], [235, 12, 28, 118], [144, 3, 170, 10],
#  [126, 150, 176, 229], [40, 166, 19, 167], [195, 170, 15, 209],
#  [44, 117, 148, 36], [82, 227, 36, 193], [122, 69, 55, 102],
#  [185, 239, 56, 183]]
# [[[137, 136, 184, 189], [151, 10, 165, 60], [138, 136, 185, 191],
#   [153, 12, 173, 52]],
#  [[102, 238, 86, 235], [159, 149, 48, 12], [146, 26, 163, 28],
#   [227, 239, 66, 118]],
#  [[144, 126, 40, 195], [3, 150, 166, 170], [170, 176, 19, 15],
#   [10, 229, 167, 209]],
#  [[44, 82, 122, 185], [117, 227, 69, 239], [148, 36, 55, 56],
#   [36, 193, 102, 183]]]

# %%
ExpandKey : [AESKeySize] -> KeySchedule
ExpandKey key = (keys @ 0, keys @@ [1 .. (Nr - 1)], keys @ `Nr)
  where   seed : [Nk][4][8]
          seed = split (split key)
          keys = ExpandKeyForever seed

fromKS : KeySchedule -> [Nr+1][4][32]
fromKS (f, ms, l) = [ formKeyWords (transpose k) | k <- [f] # ms # [l] ]
    where formKeyWords bbs = [ join bs | bs <- bbs ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:23--2:24
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 4th type parameter
#              of expression (@@)
#              at <notebook>:2:33--2:35
#   to 4
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:58--2:59
#   to 4
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# AES rounds and inverses

# %%
AESRound : (RoundKey, State) -> State
AESRound (rk, s) = AddRoundKey (rk, MixColumns (ShiftRows (SubBytes s)))

AESFinalRound : (RoundKey, State) -> State
AESFinalRound (rk, s) = AddRoundKey (rk, ShiftRows (SubBytes s))

AESInvRound : (RoundKey, State) -> State
AESInvRound (rk, s) =
      InvMixColumns (AddRoundKey (rk, InvSubBytes (InvShiftRows s)))
AESFinalInvRound : (RoundKey, State) -> State
AESFinalInvRound (rk, s) = AddRoundKey (rk, InvSubBytes (InvShiftRows s))
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:23--2:24
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 4th type parameter
#              of expression (@@)
#              at <notebook>:2:33--2:35
#   to 4
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:58--2:59
#   to 4
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# Converting a 128 bit message to a `State` and then back

# %%
msgToState : [128] -> State
msgToState msg = transpose (split (split msg))

stateToMsg : State -> [128]
stateToMsg st = join (join (transpose st))
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:23--2:24
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 4th type parameter
#              of expression (@@)
#              at <notebook>:2:33--2:35
#   to 4
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:58--2:59
#   to 4
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# AES Encryption

# %%
aesEncrypt : ([128], [AESKeySize]) -> [128]
aesEncrypt (pt, key) = stateToMsg (AESFinalRound (kFinal, rounds ! 0))
  where   (kInit, ks, kFinal) = ExpandKey key
          state0 = AddRoundKey(kInit, msgToState pt)
          rounds = [state0] # [ AESRound (rk, s) | rk <- ks
                                                 | s <- rounds
                              ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:2:1--2:11:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:66--2:67
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:23--2:24
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 4th type parameter
#              of expression (@@)
#              at <notebook>:2:33--2:35
#   to 4
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:58--2:59
#   to 4
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %% [markdown]
# AES Decryption

# %%
aesDecrypt : ([128], [AESKeySize]) -> [128]
aesDecrypt (ct, key) = stateToMsg (AESFinalInvRound (kFinal, rounds ! 0))
  where   (kFinal, ks, kInit) = ExpandKey key
          state0 = AddRoundKey(kInit, msgToState ct)
          rounds = [state0] # [ AESInvRound (rk, s) | rk <- reverse ks
                                                    | s  <- rounds
                              ]
# Out:
# Loading module Prelude
# Loading module Notebook
# [warning] at <notebook>:2:1--2:11:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:69--2:70
#   to 0
# [warning] at <notebook>:2:1--2:11:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:66--2:67
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:23--2:24
#   to 0
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 4th type parameter
#              of expression (@@)
#              at <notebook>:2:33--2:35
#   to 4
# [warning] at <notebook>:2:1--5:39:
#   Defaulting 3rd type parameter
#              of expression (@)
#              at <notebook>:2:58--2:59
#   to 4
# [warning] at <notebook>:11:26--16:31:
#   Defaulting type parameter 'bits'
#              of literal or demoted expression
#              at <notebook>:14:26--14:29
#   to 3
# [warning] at <notebook>:7:1--9:23:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:7:28--7:31
#   to 2
# [warning] at <notebook>:2:1--4:20:
#   Defaulting 2nd type parameter
#              of expression (<<<)
#              at <notebook>:2:25--2:28
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:28--6:31
#   to 2
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:39--6:42
#   to 3
# [warning] at <notebook>:6:1--6:75:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:6:50--6:53
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:30--2:33
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:41--2:44
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:52--2:55
#   to 3
# [warning] at <notebook>:2:1--3:18:
#   Defaulting 2nd type parameter
#              of expression (>>>)
#              at <notebook>:2:63--2:66
#   to 3
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:16:52--16:54
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 2nd type parameter
#              of expression (>>)
#              at <notebook>:17:40--17:42
#   to 1
# [warning] at <notebook>:11:18--17:46:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:13:21--13:22
#   to 0
# [warning] at <notebook>:2:1--3:57:
#   Defaulting 3rd type parameter
#              of expression (!)
#              at <notebook>:2:19--2:20
#   to 0

# %%
test1 where (test1,_,_) = ExpandKey 0x3243f6a8885a308d313198a2e0370734
# Out:
# [[50, 136, 49, 224], [67, 90, 49, 55], [246, 48, 152, 7],
#  [168, 141, 162, 52]]

# %%
aesEncrypt (0x3243f6a8885a308d313198a2e0370734, 0x2b7e151628aed2a6abf7158809cf4f3c) == 0x3925841d02dc09fbdc118597196a0b32
# Out:
# True
